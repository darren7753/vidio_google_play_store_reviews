# %% [markdown]
# Importing the required libraries

# %%
import numpy as np
import pandas as pd

import re
import string
import emoji

import spacy
from spacy.lang.en.stop_words import STOP_WORDS

from pymongo import MongoClient

import pickle
import os

import warnings
from pandas.core.generic import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %% [markdown]
# Loading the English model

# %%
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# Creating a connection to MongoDB

# %%
# %%time

client = MongoClient(
    os.environ["MONGODB_URL"],
    serverSelectionTimeoutMS=300000
)
db = client["vidio"]
collection = db["google_play_store_reviews"]
df_original = pd.DataFrame(list(collection.find()))
df_original = df_original.drop("_id", axis=1)
# Out:
# CPU times: total: 2.75 s
# Wall time: 1min 21s

# %% [markdown]
# Removing unnecessary rows and columns

# %%
df = df_original.copy()
df = df.replace("empty", np.nan)
df["repliedAt"] = pd.to_datetime(df["repliedAt"])
df = df.sort_values("at", ascending=False)
df = df[df["score"] <= 3]
df = df[df["content_formal_indonesian"].notna()]
df = df[~df["content_original"].str.match(r"[\u263a-\U0001f645]")]
df = df[["reviewId", "userName", "at", "content_original", "content_formal_indonesian", "content_english", "score"]]
df.head()
# Out:
#                                     reviewId          userName  \
# 241854  f9199a90-9330-4ed2-9ea0-e7f98ea65ec2  Devi Nurfalisyah
# 241857  27a2af58-142d-4d45-901b-88ab09705987        Ariii Arii
# 241858  e1d00b2f-a5c8-44cc-9d05-6dbadb086d0e     randi nugraha
# 241860  e6ad63a8-7378-4c62-8117-a9b32541c6ac       DEDExs 1319
# 241862  b8eecd63-d6bc-4571-8bb2-23f3ee884743   Taufik Kurrahim
#
#                         at                                   content_original  \
# 241854 2023-04-22 07:12:54                                       Banyak iklan
# 241857 2023-04-22 05:40:09  Nyesel aku download aplikasi ini mana iklan ny...
# 241858 2023-04-22 05:13:19                        Pliss kurangin iklan nya ya
# 241860 2023-04-22 03:19:38  Gilaaaa ini mau nonton tv malah jadi nonton ik...
# 241862 2023-04-22 01:34:44  Gajelas, masa udah beli paket langganan belum ...
#
#                                 content_formal_indonesian  \
# 241854                              Terlalu banyak iklan.
# 241857  Saya sangat menyesal telah mengunduh aplikasi ...
# 241858                        Tolong kurangi iklannya ya.
# 241860  Sungguh tidak masuk akal, saya ingin menonton ...
# 241862  Saya merasa sangat kecewa dengan Gajelas. Masa...
#
#                                           content_english  score
# 241854                             Excessive advertising.      1
# 241857  I deeply regret downloading this application b...      1
# 241858         Please reduce the number of ads displayed.      1
# 241860  It's really ridiculous, I want to watch TV but...      1
# 241862  I am very disappointed with Gajelas. How come,...      1

# %%
df.shape
# Out:
# (20428, 7)

# %% [markdown]
# Cleaning the reviews

# %%
for i in ["content_formal_indonesian", "content_english"]:
    df[i] = df[i].str.replace("Baris 1", "")
    df[i] = df[i].str.replace("Baris 2", "")
    df[i] = df[i].str.replace("(", "", regex=True)
    df[i] = df[i].str.replace(")", "", regex=True)
    df[i] = df[i].apply(lambda x: emoji.replace_emoji(x, ""))

# %%
df["content_english"] = df["content_english"].str.replace("ads", "advertisements")

# %%
replace1 = list(df[df["content_english"].str.contains("Note")].index)
replace2 = list(df[(df["content_english"].str.contains("Indonesian", case=False)) & (df["content_english"].str.contains("dictionary", case=False))].index)
replace3 = list(df[(df["content_english"].str.contains("Indonesian", case=False)) & (df["content_english"].str.contains("language", case=False))].index)

replace = sorted(list(set(replace1 + replace2 + replace3)))

df.loc[df.index.isin(replace), ["content_formal_indonesian", "content_english"]] = df.loc[df.index.isin(replace), "content_original"]

# %%
def clean(text):
    text = text.lower()
    text = re.sub(r'\$\w*', '',str(text ))
    text = re.sub(r'\bRT\b', '', text)
    text = re.sub('b\'', '', text)
    text = re.sub(r'\.{2,}', ' ', text)
    text = re.sub('@[^\s]+','',text)
    text = re.sub(r'^RT[\s]+', '', text)
    text = re.sub('[0-9]+', '', text)
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r'(\s)#\w+', r'\1', text)
    text = text.strip(' "\'')
    text = re.sub(r'\s+', ' ', text)
    text = text.translate(str.maketrans("","",string.punctuation))
    text = text.replace("\n",' ')
    return text 

df["content_cleaned"] = df["content_english"].apply(clean)
df = df[df["content_cleaned"].str.strip().replace("\s+", "") != ""]
df = df[df["content_cleaned"] != ""]
df.head()
# Out:
#                                     reviewId          userName  \
# 241854  f9199a90-9330-4ed2-9ea0-e7f98ea65ec2  Devi Nurfalisyah
# 241857  27a2af58-142d-4d45-901b-88ab09705987        Ariii Arii
# 241858  e1d00b2f-a5c8-44cc-9d05-6dbadb086d0e     randi nugraha
# 241860  e6ad63a8-7378-4c62-8117-a9b32541c6ac       DEDExs 1319
# 241862  b8eecd63-d6bc-4571-8bb2-23f3ee884743   Taufik Kurrahim
#
#                         at                                   content_original  \
# 241854 2023-04-22 07:12:54                                       Banyak iklan
# 241857 2023-04-22 05:40:09  Nyesel aku download aplikasi ini mana iklan ny...
# 241858 2023-04-22 05:13:19                        Pliss kurangin iklan nya ya
# 241860 2023-04-22 03:19:38  Gilaaaa ini mau nonton tv malah jadi nonton ik...
# 241862 2023-04-22 01:34:44  Gajelas, masa udah beli paket langganan belum ...
#
#                                 content_formal_indonesian  \
# 241854                              Terlalu banyak iklan.
# 241857  Saya sangat menyesal telah mengunduh aplikasi ...
# 241858                        Tolong kurangi iklannya ya.
# 241860  Sungguh tidak masuk akal, saya ingin menonton ...
# 241862  Saya merasa sangat kecewa dengan Gajelas. Masa...
#
#                                           content_english  score  \
# 241854                             Excessive advertising.      1
# 241857  I deeply regret downloading this application b...      1
# 241858  Please reduce the number of advertisements dis...      1
# 241860  It's really ridiculous, I want to watch TV but...      1
# 241862  I am very disappointed with Gajelas. How come,...      1
#
#                                           content_cleaned
# 241854                              excessive advertising
# 241857  i deeply regret downloading this application b...
# 241858  please reduce the number of advertisements dis...
# 241860  its really ridiculous i want to watch tv but a...
# 241862  i am very disappointed with gajelas how come w...

# %% [markdown]
# Lemmatizing the reviews

# %%
# %%time

def lemmatization(text):
    doc = nlp(text)
    lemmatized_text = " ".join([token.lemma_ for token in doc if not token.is_stop and token.lang_ == 'en'])
    return lemmatized_text

df["content_cleaned"] = df["content_cleaned"].apply(nlp)
df["content_cleaned"] = df["content_cleaned"].apply(lambda x: lemmatization(x.text))
df.head()
# Out:
# CPU times: total: 3min 2s
# Wall time: 5min 33s
#                                     reviewId          userName  \
# 241854  f9199a90-9330-4ed2-9ea0-e7f98ea65ec2  Devi Nurfalisyah
# 241857  27a2af58-142d-4d45-901b-88ab09705987        Ariii Arii
# 241858  e1d00b2f-a5c8-44cc-9d05-6dbadb086d0e     randi nugraha
# 241860  e6ad63a8-7378-4c62-8117-a9b32541c6ac       DEDExs 1319
# 241862  b8eecd63-d6bc-4571-8bb2-23f3ee884743   Taufik Kurrahim
#
#                         at                                   content_original  \
# 241854 2023-04-22 07:12:54                                       Banyak iklan
# 241857 2023-04-22 05:40:09  Nyesel aku download aplikasi ini mana iklan ny...
# 241858 2023-04-22 05:13:19                        Pliss kurangin iklan nya ya
# 241860 2023-04-22 03:19:38  Gilaaaa ini mau nonton tv malah jadi nonton ik...
# 241862 2023-04-22 01:34:44  Gajelas, masa udah beli paket langganan belum ...
#
#                                 content_formal_indonesian  \
# 241854                              Terlalu banyak iklan.
# 241857  Saya sangat menyesal telah mengunduh aplikasi ...
# 241858                        Tolong kurangi iklannya ya.
# 241860  Sungguh tidak masuk akal, saya ingin menonton ...
# 241862  Saya merasa sangat kecewa dengan Gajelas. Masa...
#
#                                           content_english  score  \
# 241854                             Excessive advertising.      1
# 241857  I deeply regret downloading this application b...      1
# 241858  Please reduce the number of advertisements dis...      1
# 241860  It's really ridiculous, I want to watch TV but...      1
# 241862  I am very disappointed with Gajelas. How come,...      1
#
#                                           content_cleaned
# 241854                              excessive advertising
# 241857  deeply regret download application advertiseme...
# 241858                reduce number advertisement display
# 241860  ridiculous want watch tv endless advertisement...
# 241862  disappointed gajela come buy subscription pack...

# %% [markdown]
# Performing another cleaning

# %%
for i in ["content_cleaned"]:
    df[i] = df[i].str.replace("world", "", case=False)
    df[i] = df[i].str.replace("cup", "", case=False)
    df[i] = df[i].str.replace("final", "", case=False)
    df[i] = df[i].str.replace("wc", "", case=False)
    df[i] = df[i].str.replace("football", "", case=False)
    df[i] = df[i].str.replace("app ", " ", case=False)
    df[i] = df[i].str.replace("application", "", case=False)
    df[i] = df[i].str.replace("apk", "", case=False)

# %% [markdown]
# Creating a CountVectorizer to convert a collection of text documents into a matrix of token counts

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_df=0.95, min_df=2, stop_words="english")
dtm = cv.fit_transform(df["content_cleaned"])

# %% [markdown]
# Creating an LDA model with 4 topics

# %%
# %%time

from sklearn.decomposition import LatentDirichletAllocation

LDA = LatentDirichletAllocation(n_components=4, random_state=42)
LDA.fit(dtm)
# Out:
# CPU times: total: 23.7 s
# Wall time: 41.1 s
# LatentDirichletAllocation(n_components=4, random_state=42)

# %% [markdown]
# Showing the top 15 words on each of the 4 topics

# %%
df_top_15_words = pd.DataFrame(
    data=[cv.get_feature_names_out()[i][::-1] for i in [topic.argsort()[-15:] for topic in LDA.components_]],
    columns=[f"Words {index}" for index in range(15)],
    index=[f"Topic {index}" for index in range(len(LDA.components_))]
)
df_top_15_words
# Out:
#                Words 0   Words 1    Words 2 Words 3  Words 4  Words 5  \
# Topic 0            bad     watch   download    good     live     slow
# Topic 1        package  purchase      watch     buy  payment   unable
# Topic 2  advertisement     watch      video      tv      fix     good
# Topic 3          watch     error  subscribe     log      pay  account
#
#               Words 6     Words 7    Words 8  Words 9   Words 10  \
# Topic 0          star   streaming  broadcast      try        pay
# Topic 1  subscription         pay    premium   credit  subscribe
# Topic 2       quality        play      movie  network     update
# Topic 3         match  experience   suddenly     want  difficult
#
#              Words 11 Words 12 Words 13 Words 14
# Topic 0          free     time     code  useless
# Topic 1       balance   deduct      use  premier
# Topic 2          like     poor     time     open
# Topic 3  subscription       ve      try    login

# %% [markdown]
# Attaching the discovered topics to the original reviews

# %%
topic_results = LDA.transform(dtm)
df["topic"] = topic_results.argmax(axis=1)

# %% [markdown]
# Calculating the number of reviews that are associated with each of the 4 topics

# %%
df["topic"].value_counts()
# Out:
# 3    6052
# 2    5218
# 0    4571
# 1    4522
# Name: topic, dtype: int64

# %% [markdown]
# Adding labels to the topics

# %%
def topic_names(x):
    if x == 0:
        return "Bad Application"
    elif x == 1:
        return "Package"
    elif x == 2:
        return "Advertisement"
    else:
        return "Watching Experience"
    
df["topic"] = df["topic"].apply(topic_names)
df
# Out:
#                                     reviewId                 userName  \
# 241854  f9199a90-9330-4ed2-9ea0-e7f98ea65ec2         Devi Nurfalisyah
# 241857  27a2af58-142d-4d45-901b-88ab09705987               Ariii Arii
# 241858  e1d00b2f-a5c8-44cc-9d05-6dbadb086d0e            randi nugraha
# 241860  e6ad63a8-7378-4c62-8117-a9b32541c6ac              DEDExs 1319
# 241862  b8eecd63-d6bc-4571-8bb2-23f3ee884743          Taufik Kurrahim
# ...                                      ...                      ...
# 32916   1709ac0b-7f24-4a06-a48c-fc2b399fc84a              hartono ang
# 32914   2f0085d1-e91f-4b6c-8ce3-de8e341dde2f   Alif Choirul Maftuchin
# 32547   cf112c5b-446b-4b30-b5d2-c06e3cd6ea81            Ristyan Vidya
# 32915   a384369c-7aa9-48d7-ac28-e2244ea2cb65  eric abednego maranatha
# 32619   f39fda93-3ace-4f0e-9344-28d1fd068be9           Muhammad Zidni
#
#                         at                                   content_original  \
# 241854 2023-04-22 07:12:54                                       Banyak iklan
# 241857 2023-04-22 05:40:09  Nyesel aku download aplikasi ini mana iklan ny...
# 241858 2023-04-22 05:13:19                        Pliss kurangin iklan nya ya
# 241860 2023-04-22 03:19:38  Gilaaaa ini mau nonton tv malah jadi nonton ik...
# 241862 2023-04-22 01:34:44  Gajelas, masa udah beli paket langganan belum ...
# ...                    ...                                                ...
# 32916  2022-08-27 20:16:12  Aplikasi yang buruk .. nonton liga inggris nge...
# 32914  2022-08-27 20:16:12  Gak bisa buat nonton, PADAHAL SUDAH LANGGANAN ...
# 32547  2022-08-27 20:16:06  Gua udh byar full 1 thun.. error kga bsa nnton...
# 32915  2022-08-27 20:15:52  Parah lg seru" nonton liga Inggris eh ilang pa...
# 32619  2022-08-27 20:15:49                   Udah bayar siaran masih ajh eror
#
#                                 content_formal_indonesian  \
# 241854                              Terlalu banyak iklan.
# 241857  Saya sangat menyesal telah mengunduh aplikasi ...
# 241858                        Tolong kurangi iklannya ya.
# 241860  Sungguh tidak masuk akal, saya ingin menonton ...
# 241862  Saya merasa sangat kecewa dengan Gajelas. Masa...
# ...                                                   ...
# 32916   Aplikasi yang buruk mengalami lag saat menonto...
# 32914   Tidak dapat digunakan untuk menonton, WALAUPUN...
# 32547   Saya telah melakukan pembayaran penuh selama s...
# 32915   Nonton liga Inggris menjadi semakin seru, teta...
# 32619   Sudah membayar siaran tetapi masih mengalami k...
#
#                                           content_english  score  \
# 241854                             Excessive advertising.      1
# 241857  I deeply regret downloading this application b...      1
# 241858  Please reduce the number of advertisements dis...      1
# 241860  It's really ridiculous, I want to watch TV but...      1
# 241862  I am very disappointed with Gajelas. How come,...      1
# ...                                                   ...    ...
# 32916   The application is bad, it lags while watching...      2
# 32914   Cannot be used for watching, EVEN THOUGH ALREA...      1
# 32547   I have paid in full for one year, but I cannot...      1
# 32915   Watching the Premier League was getting even m...      1
# 32619   Have paid for the broadcast but still experien...      1
#
#                                           content_cleaned                topic
# 241854                              excessive advertising        Advertisement
# 241857  deeply regret download  advertisement unclear ...      Bad Application
# 241858                reduce number advertisement display        Advertisement
# 241860  ridiculous want watch tv endless advertisement...        Advertisement
# 241862  disappointed gajela come buy subscription pack...              Package
# ...                                                   ...                  ...
# 32916    bad lag watch english league match provide sa...              Package
# 32914                               watch subscribe goblk  Watching Experience
# 32547                        pay year watch poor quality         Advertisement
# 32915   watch premier league get exciting suddenly dis...  Watching Experience
# 32619                      pay broadcast experience error  Watching Experience
#
# [20363 rows x 9 columns]

# %% [markdown]
# Merging the topics to the original dataframe

# %%
df_merged = pd.merge(df_original, df[["topic"]], left_index=True, right_index=True, how="outer")
df_merged = df_merged.fillna("empty")
df_merged.head(10)
# Out:
#                                reviewId  \
# 0  e2a5116c-6baa-4a19-94b1-0563d0f49823
# 1  aa568a26-9a64-43ac-acc0-551e9723645a
# 2  bdb23d0e-47bf-4e89-92eb-2061460ad6c0
# 3  d2518700-29b4-4ea2-9538-ce92e95ae318
# 4  85e286b1-db43-44c7-86f7-f82e329e4ae8
# 5  4bd5f616-3c50-442d-a0a8-92cc80783357
# 6  010cc55b-358c-4a8a-b789-c87a08209c7e
# 7  6f181258-4462-4d1a-a387-9dfa504f4181
# 8  0d59dd1d-cb45-45cb-b9a4-3a4e540bfbc6
# 9  f99f20e2-c07e-4e10-a821-a712adf7043a
#
#                                       userName  \
# 0                                 Bibah Garuda
# 1                                    Nuke Yuli
# 2                                   reva hasan
# 3                                     Ucu Baan
# 4                               Hafiz Fadillah
# 5                                        Va Ra
# 6                                    MaZ ambon
# 7  online “Nobila Syalwa Rahmanita” arsitektur
# 8                                Miranda Randa
# 9                                     Mau Kana
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AGNmyx...
# 1  https://play-lh.googleusercontent.com/a/AGNmyx...
# 2  https://play-lh.googleusercontent.com/a/AGNmyx...
# 3  https://play-lh.googleusercontent.com/a/AGNmyx...
# 4  https://play-lh.googleusercontent.com/a/AGNmyx...
# 5  https://play-lh.googleusercontent.com/a/AGNmyx...
# 6  https://play-lh.googleusercontent.com/a/AGNmyx...
# 7  https://play-lh.googleusercontent.com/a-/ACB-R...
# 8  https://play-lh.googleusercontent.com/a/AGNmyx...
# 9  https://play-lh.googleusercontent.com/a/AGNmyx...
#
#                                     content_original  \
# 0  Saya baik min,walaupun suka ngefreeze and bany...
# 1  Vidio Ini Sangat Bagus Dan KualitasNya Dan Apl...
# 2           Saya bisa nonton tv tanpa menggunakan tv
# 3                                               baik
# 4                                  Ada vidio magic 5
# 5  Saya belum dowload si saya kasih aja bintang l...
# 6                                              Siilp
# 7                   Bagusss bagettt filimnya magic 5
# 8  Saya emosi sama apk ini kebanyakan iklan mendi...
# 9                          Mending hapus aja apk ini
#
#                            content_formal_indonesian  \
# 0  Saya merasa baik min, walaupun sering mengalam...
# 1  Video ini sangat bagus dan kualitasnya, dan ap...
# 2       Saya dapat menonton tv tanpa menggunakan tv.
# 3                                            Baiklah
# 4                                 Ada video magic 5.
# 5  Saya belum mengunduhnya, tapi saya beri lima b...
# 6                                          Seni Rupa
# 7                   Filmnya Bagusss bagiett magic 5.
# 8  Saya merasa kesal dengan aplikasi ini karena t...
# 9                          Mohon hapus aplikasi ini.
#
#                                      content_english  score  thumbsUpCount  \
# 0  I am doing well, despite frequently experienci...      3              0
# 1  This video is very good in quality and the app...      5              0
# 2                 I can watch TV without using a TV.      3              0
# 3                                           Kindness      4              0
# 4  Please download this application to watch videos.      5              0
# 5  I haven't downloaded it yet, but I'll give it ...      5              0
# 6                                          Fine Arts      3              0
# 7      The movie is really good, especially Magic 5.      5              0
# 8  I am frustrated with this application because ...      1              0
# 9               I suggest deleting this application.      1              0
#
#   reviewCreatedVersion                  at  \
# 0    6.1.10-11c7d4bab7 2023-04-07 06:25:21
# 1    6.1.10-11c7d4bab7 2023-04-07 06:12:32
# 2    6.1.10-11c7d4bab7 2023-04-07 05:58:47
# 3   5.90.11-313f2fa36c 2023-04-07 05:56:22
# 4                empty 2023-04-07 05:52:38
# 5                empty 2023-04-07 04:34:26
# 6                empty 2023-04-07 03:11:36
# 7     6.0.5-f68a5157fa 2023-04-07 03:55:22
# 8     6.0.5-f68a5157fa 2023-04-07 02:55:41
# 9                empty 2023-04-07 02:02:48
#
#                                         replyContent            repliedAt  \
# 0  Hai kak Bibah, ada banyak tayangan yang bisa k...  2023-04-07 06:33:41
# 1  Hai kak Nuke, thank you for your five stars. F...  2023-04-07 06:33:15
# 2  Hai Kak Reva, terima kasih ya atas rating dan ...  2023-04-07 06:32:50
# 3  Hai Kak Ucu, thank you for your positive feedb...  2023-04-07 06:31:53
# 4  Hai kak Hafiz, thank you for your 5 stars. Kam...  2023-04-07 06:32:13
# 5  Hai Sahabat Vidio, terima kasih atas bintang l...  2023-04-07 04:45:15
# 6  Hai Sahabat Vidio, terima kasih sudah mengguna...  2023-04-07 03:16:40
# 7  Hai Sahabat Vidio, terima kasih atas bintang l...  2023-04-07 04:45:09
# 8  Hai kak Miranda, terima kasih telah menggunaka...  2023-04-07 03:03:32
# 9  Hai Sahabat Vidio, mohon maaf ketidaknyamanan ...  2023-04-07 02:06:48
#
#              topic
# 0    Advertisement
# 1            empty
# 2    Advertisement
# 3            empty
# 4            empty
# 5            empty
# 6    Advertisement
# 7            empty
# 8    Advertisement
# 9  Bad Application

# %% [markdown]
# Saving both the CountVectorizer and LDA model

# %%
with open("count_vectorizer.pkl", "wb") as f:
    pickle.dump(cv, f)
    
with open("lda_model.pkl", "wb") as f:
    pickle.dump(LDA, f)

# %% [markdown]
# Replacing existing values with new ones

# %%
# %%time

client = MongoClient(
    os.environ["MONGODB_URL"],
    serverSelectionTimeoutMS=300000
)
db = client["vidio"]
collection = db["google_play_store_reviews"]
df_merged_dict = df_merged.to_dict("records")
collection.delete_many({})

batch_size = 1_000
num_records = len(df_merged_dict)
num_batches = num_records // batch_size

if num_records % batch_size != 0:
    num_batches += 1

for i in range(num_batches):
    start_idx = i * batch_size
    end_idx = min(start_idx + batch_size, num_records)
    batch = df_merged_dict[start_idx:end_idx]
    
    if batch:
        collection.insert_many(batch)

print("Data replaced successfully")
# Out:
# Data replaced successfully
# CPU times: total: 5.81 s
# Wall time: 11min 10s
